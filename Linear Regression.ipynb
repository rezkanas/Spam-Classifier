# %% [markdown]
# # Selecting Linear's Hyperparameters:
#  I have considered here multiple combinations of:
#   * **Threshold** is the threshold used in classifying the prediction into 0 and 1.
#   * **Number Fold** is the numbers of foldes that training data are split into. This is used in cross valdiation excercise.
#
# I plug a serie of combinations in `create_classifier` in order to measure the weighted overall accuracy on unseen data. I, then, select the hyperparameters that got the best accuracy to go into the final module that I used for prediction on test data.

# %%
# Multivariate Linear classifiers with a hard threshold |selecting_hyperparameters
import numpy as np
import itertools
import time 

start_time = time.process_time()

training_spam = np.loadtxt(open("data/training_spam.csv"), delimiter=",").astype(int)
testing_spam = np.loadtxt(open("data/testing_spam.csv"), delimiter=",").astype(int)
test_data = testing_spam[:, 1:]
test_labels = testing_spam[:, 0]

class SpamClassifier:
    def __init__(self,threshold_classifier):
        self.threshold_classifier= threshold_classifier
        
    def train(self, training_data):
        n_samples, n_features = training_data[:,1:].shape
        x= training_data[:,1:]
        y= training_data[:,0]
        x=np.concatenate((np.ones((training_data.shape[0],1), dtype =int),x), axis=1)
        #normal equation
        self.weights= np.dot(np.dot(np.linalg.inv(np.dot(x.T, x)), x.T), y)

    
    def predict(self, new_data):
        new_data = np.concatenate((np.ones((new_data.shape[0],1), dtype =int),new_data), axis=1)
        linear_model = np.dot(self.weights.T, new_data.T)
        
        return np.where(linear_model <= self.threshold_classifier,0,1)
    

def cross_validation(training_spam, item):
    max_accuracy = 0
    averaged_accuracy = 0
    threshold, k_fold=item
    x_training= training_spam[:,1:]
    y_training= training_spam[:,0]
    x = np.split(x_training, x_training.shape[0]/k_fold, axis=0)
    y = np.split(y_training, y_training.shape[0]/k_fold, axis=0)
    for i in range(len(x)):
        x_temp=np.concatenate(x[0:i]+x[i+1:])
        y_temp=np.concatenate(y[0:i]+y[i+1:])
        y_temp=y_temp.reshape(y_temp.shape[0],1)
        temp_data = np.concatenate((y_temp,x_temp), axis=1)
        classifier = SpamClassifier(threshold)
        classifier.train(temp_data)
        final_y_predict_temp = classifier.predict(x[i])
        accuracy = np.count_nonzero(final_y_predict_temp == y[i].reshape(final_y_predict_temp.shape))/final_y_predict_temp.shape[0]
        
        if accuracy > max_accuracy:
            max_accuracy = accuracy
            max_classifier= classifier
        averaged_accuracy += accuracy
    averaged_accuracy = averaged_accuracy/len(x)
    return max_classifier, max_accuracy, averaged_accuracy

def create_classifier(training_spam, item):
    classifier = cross_validation(training_spam, item)
    return classifier

i = 0.4
threshold= [i+0.01*k for k in range(30)]
k_fold = [10,20,25, 50, 100, 200, 500]
output_list = list(itertools.product(threshold, k_fold))
max_weighted_accuracy=0
for item in output_list:
    classifier, max_accuracy_train, averaged_accuracy_train = create_classifier(training_spam, item)
    end_time = time.process_time()
    
    test_data = testing_spam[:, 1:]
    test_labels = testing_spam[:, 0]

    predictions = classifier.predict(test_data)
    accuracy = np.count_nonzero(predictions == test_labels)/test_labels.shape[0]
    
    
    
    weighted_accuracy = accuracy * test_data.shape[0] / (test_data.shape[0]+(training_spam.shape[0]/item[-1])) \
    + averaged_accuracy_train * (training_spam.shape[0]/item[-1]) / (test_data.shape[0]+(training_spam.shape[0]/item[-1]))
    

    if weighted_accuracy > max_weighted_accuracy:
            dic={}
            
            max_weighted_accuracy=weighted_accuracy
            max_accuracy = accuracy
            maxi_accuracy_train = max_accuracy_train
            averaged_accuracy_train = averaged_accuracy_train
        
            max_item = item
            
            max_time = int(end_time-start_time)
    elif weighted_accuracy == max_weighted_accuracy:
        dic[item]=[weighted_accuracy, accuracy, averaged_accuracy_train, max_accuracy_train]
        
         
    print("&&"*50)
    print(f"Weighted accuracy is {weighted_accuracy} when classification threshold and k-folds are {item} respectively.")
    print()
    print(f"Accuracy on test data is: {accuracy}, averaged accuracy on train data is: {averaged_accuracy_train}")
    print(f"This took", int(end_time-start_time), "seconds to solve.")
    print()
    print()
    print(f"**The best overall accuracy on test data is so far standing at: {max_weighted_accuracy} when classification threshold and k-folds are {max_item}")
    print(f"Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {dic}")
    print()
    print()
    print()





print()
print('^'*250)
print(f"When classification threshold and k-folds are {max_item} respectively, the expected overall weighted accuracy on unseen data is: {max_weighted_accuracy}")
print(f"This module is {max_accuracy} accurat on test data")
print(f"Whereas, averaged accuracy on train data is {averaged_accuracy_train}, and topped at {maxi_accuracy_train}")
print(f"This module takes {max_time} seconds to solve.")
print(f"Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {dic}")

# pass on the result to the final module below
threshold, k_fold = max_item
# Out:
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.911 when classification threshold and k-folds are (0.4, 10) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9160000000000003
# This took 1 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.911 when classification threshold and k-folds are (0.4, 10)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9105454545454545 when classification threshold and k-folds are (0.4, 20) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.916
# This took 2 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.911 when classification threshold and k-folds are (0.4, 10)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9087407407407408 when classification threshold and k-folds are (0.4, 25) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9180000000000004
# This took 3 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.911 when classification threshold and k-folds are (0.4, 10)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9120384615384616 when classification threshold and k-folds are (0.4, 50) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.9129999999999999
# This took 3 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.9120384615384616 when classification threshold and k-folds are (0.4, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9109803921568628 when classification threshold and k-folds are (0.4, 100) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.86
# This took 3 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.9120384615384616 when classification threshold and k-folds are (0.4, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.910019801980198 when classification threshold and k-folds are (0.4, 200) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9120000000000001
# This took 3 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.9120384615384616 when classification threshold and k-folds are (0.4, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.906011952191235 when classification threshold and k-folds are (0.4, 500) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.909
# This took 3 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.9120384615384616 when classification threshold and k-folds are (0.4, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9115 when classification threshold and k-folds are (0.41000000000000003, 10) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9190000000000004
# This took 5 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.9120384615384616 when classification threshold and k-folds are (0.4, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9109090909090909 when classification threshold and k-folds are (0.41000000000000003, 20) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9200000000000002
# This took 6 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.9120384615384616 when classification threshold and k-folds are (0.4, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.910962962962963 when classification threshold and k-folds are (0.41000000000000003, 25) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9230000000000004
# This took 7 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.9120384615384616 when classification threshold and k-folds are (0.4, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50) respectively.
#
# Accuracy on test data is: 0.916, averaged accuracy on train data is: 0.9179999999999999
# This took 7 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9091568627450981 when classification threshold and k-folds are (0.41000000000000003, 100) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.867
# This took 7 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.914 when classification threshold and k-folds are (0.41000000000000003, 200) respectively.
#
# Accuracy on test data is: 0.914, averaged accuracy on train data is: 0.914
# This took 7 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9020438247011952 when classification threshold and k-folds are (0.41000000000000003, 500) respectively.
#
# Accuracy on test data is: 0.902, averaged accuracy on train data is: 0.913
# This took 7 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9118333333333334 when classification threshold and k-folds are (0.42000000000000004, 10) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9210000000000004
# This took 9 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9071818181818182 when classification threshold and k-folds are (0.42000000000000004, 20) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.919
# This took 10 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9126666666666667 when classification threshold and k-folds are (0.42000000000000004, 25) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.9210000000000005
# This took 10 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9085 when classification threshold and k-folds are (0.42000000000000004, 50) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.921
# This took 11 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9091372549019608 when classification threshold and k-folds are (0.42000000000000004, 100) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.866
# This took 11 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9081287128712872 when classification threshold and k-folds are (0.42000000000000004, 200) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.921
# This took 11 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8960717131474103 when classification threshold and k-folds are (0.42000000000000004, 500) respectively.
#
# Accuracy on test data is: 0.896, averaged accuracy on train data is: 0.914
# This took 11 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9116666666666667 when classification threshold and k-folds are (0.43000000000000005, 10) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9200000000000006
# This took 13 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9112727272727272 when classification threshold and k-folds are (0.43000000000000005, 20) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9240000000000002
# This took 13 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9144444444444445 when classification threshold and k-folds are (0.43000000000000005, 25) respectively.
#
# Accuracy on test data is: 0.914, averaged accuracy on train data is: 0.9200000000000005
# This took 14 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9104230769230769 when classification threshold and k-folds are (0.43000000000000005, 50) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9209999999999999
# This took 14 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9130588235294118 when classification threshold and k-folds are (0.43000000000000005, 100) respectively.
#
# Accuracy on test data is: 0.914, averaged accuracy on train data is: 0.866
# This took 14 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9140792079207921 when classification threshold and k-folds are (0.43000000000000005, 200) respectively.
#
# Accuracy on test data is: 0.914, averaged accuracy on train data is: 0.9219999999999999
# This took 15 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9139920318725099 when classification threshold and k-folds are (0.43000000000000005, 500) respectively.
#
# Accuracy on test data is: 0.914, averaged accuracy on train data is: 0.912
# This took 15 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9125000000000001 when classification threshold and k-folds are (0.44, 10) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9250000000000004
# This took 16 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9113636363636364 when classification threshold and k-folds are (0.44, 20) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9250000000000003
# This took 17 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9111111111111111 when classification threshold and k-folds are (0.44, 25) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9250000000000005
# This took 18 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9085769230769231 when classification threshold and k-folds are (0.44, 50) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.923
# This took 18 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9111372549019608 when classification threshold and k-folds are (0.44, 100) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.868
# This took 18 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9140792079207921 when classification threshold and k-folds are (0.44, 200) respectively.
#
# Accuracy on test data is: 0.914, averaged accuracy on train data is: 0.9219999999999999
# This took 18 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.908011952191235 when classification threshold and k-folds are (0.44, 500) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.911
# This took 18 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.91 when classification threshold and k-folds are (0.45, 10) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.9300000000000003
# This took 20 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9082727272727273 when classification threshold and k-folds are (0.45, 20) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.9310000000000004
# This took 21 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9133333333333333 when classification threshold and k-folds are (0.45, 25) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.9300000000000004
# This took 21 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9068846153846154 when classification threshold and k-folds are (0.45, 50) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.9289999999999999
# This took 22 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9072156862745098 when classification threshold and k-folds are (0.45, 100) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.868
# This took 22 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9120990099009901 when classification threshold and k-folds are (0.45, 200) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.9219999999999999
# This took 22 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9080398406374501 when classification threshold and k-folds are (0.45, 500) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.918
# This took 22 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9115000000000001 when classification threshold and k-folds are (0.46, 10) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9290000000000004
# This took 24 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9063636363636364 when classification threshold and k-folds are (0.46, 20) respectively.
#
# Accuracy on test data is: 0.904, averaged accuracy on train data is: 0.9300000000000004
# This took 25 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.906 when classification threshold and k-folds are (0.46, 25) respectively.
#
# Accuracy on test data is: 0.904, averaged accuracy on train data is: 0.9310000000000004
# This took 25 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9068461538461539 when classification threshold and k-folds are (0.46, 50) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.9279999999999999
# This took 25 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9052549019607843 when classification threshold and k-folds are (0.46, 100) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.868
# This took 26 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9101485148514852 when classification threshold and k-folds are (0.46, 200) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.925
# This took 26 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9060438247011952 when classification threshold and k-folds are (0.46, 500) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.917
# This took 26 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.91 when classification threshold and k-folds are (0.47000000000000003, 10) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.9300000000000003
# This took 27 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9098181818181819 when classification threshold and k-folds are (0.47000000000000003, 20) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9280000000000004
# This took 28 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9077037037037038 when classification threshold and k-folds are (0.47000000000000003, 25) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.9290000000000005
# This took 29 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9069230769230769 when classification threshold and k-folds are (0.47000000000000003, 50) respectively.
#
# Accuracy on test data is: 0.906, averaged accuracy on train data is: 0.93
# This took 29 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9072941176470588 when classification threshold and k-folds are (0.47000000000000003, 100) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.8720000000000001
# This took 29 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9022079207920792 when classification threshold and k-folds are (0.47000000000000003, 200) respectively.
#
# Accuracy on test data is: 0.902, averaged accuracy on train data is: 0.923
# This took 29 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9139999999999999 when classification threshold and k-folds are (0.47000000000000003, 500) respectively.
#
# Accuracy on test data is: 0.914, averaged accuracy on train data is: 0.914
# This took 29 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9115000000000001 when classification threshold and k-folds are (0.48000000000000004, 10) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9290000000000005
# This took 31 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9099090909090909 when classification threshold and k-folds are (0.48000000000000004, 20) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9290000000000004
# This took 32 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9097777777777779 when classification threshold and k-folds are (0.48000000000000004, 25) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9320000000000006
# This took 33 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9088461538461539 when classification threshold and k-folds are (0.48000000000000004, 50) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9299999999999999
# This took 33 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9092352941176471 when classification threshold and k-folds are (0.48000000000000004, 100) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.8710000000000001
# This took 33 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9041980198019802 when classification threshold and k-folds are (0.48000000000000004, 200) respectively.
#
# Accuracy on test data is: 0.904, averaged accuracy on train data is: 0.924
# This took 33 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9120039840637449 when classification threshold and k-folds are (0.48000000000000004, 500) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.913
# This took 33 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9141666666666668 when classification threshold and k-folds are (0.49, 10) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.9250000000000006
# This took 35 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9115454545454545 when classification threshold and k-folds are (0.49, 20) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9270000000000003
# This took 36 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9113333333333333 when classification threshold and k-folds are (0.49, 25) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9280000000000005
# This took 36 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9107692307692308 when classification threshold and k-folds are (0.49, 50) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9299999999999999
# This took 37 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9091764705882354 when classification threshold and k-folds are (0.49, 100) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.868
# This took 37 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9022079207920792 when classification threshold and k-folds are (0.49, 200) respectively.
#
# Accuracy on test data is: 0.902, averaged accuracy on train data is: 0.923
# This took 37 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9099999999999999 when classification threshold and k-folds are (0.49, 500) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.91
# This took 37 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9108333333333335 when classification threshold and k-folds are (0.5, 10) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9250000000000006
# This took 39 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9096363636363637 when classification threshold and k-folds are (0.5, 20) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9260000000000003
# This took 39 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9113333333333333 when classification threshold and k-folds are (0.5, 25) respectively.
#
# Accuracy on test data is: 0.91, averaged accuracy on train data is: 0.9280000000000003
# This took 40 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9086538461538461 when classification threshold and k-folds are (0.5, 50) respectively.
#
# Accuracy on test data is: 0.908, averaged accuracy on train data is: 0.9249999999999998
# This took 40 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.9110784313725491 when classification threshold and k-folds are (0.5, 100) respectively.
#
# Accuracy on test data is: 0.912, averaged accuracy on train data is: 0.8649999999999999
# This took 41 seconds to solve.
#
#
# ...
# Weighted accuracy is 0.8808235294117648 when classification threshold and k-folds are (0.66, 100) respectively.
#
# Accuracy on test data is: 0.882, averaged accuracy on train data is: 0.8219999999999998
# This took 101 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.879980198019802 when classification threshold and k-folds are (0.66, 200) respectively.
#
# Accuracy on test data is: 0.88, averaged accuracy on train data is: 0.8779999999999999
# This took 101 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8799601593625498 when classification threshold and k-folds are (0.66, 500) respectively.
#
# Accuracy on test data is: 0.88, averaged accuracy on train data is: 0.87
# This took 101 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8723333333333334 when classification threshold and k-folds are (0.67, 10) respectively.
#
# Accuracy on test data is: 0.872, averaged accuracy on train data is: 0.8740000000000001
# This took 102 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8719090909090909 when classification threshold and k-folds are (0.67, 20) respectively.
#
# Accuracy on test data is: 0.872, averaged accuracy on train data is: 0.8709999999999998
# This took 103 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.874 when classification threshold and k-folds are (0.67, 25) respectively.
#
# Accuracy on test data is: 0.874, averaged accuracy on train data is: 0.8740000000000003
# This took 104 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.874 when classification threshold and k-folds are (0.67, 50) respectively.
#
# Accuracy on test data is: 0.874, averaged accuracy on train data is: 0.874
# This took 104 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8728823529411764 when classification threshold and k-folds are (0.67, 100) respectively.
#
# Accuracy on test data is: 0.874, averaged accuracy on train data is: 0.817
# This took 104 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.875960396039604 when classification threshold and k-folds are (0.67, 200) respectively.
#
# Accuracy on test data is: 0.876, averaged accuracy on train data is: 0.8719999999999999
# This took 105 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8799521912350597 when classification threshold and k-folds are (0.67, 500) respectively.
#
# Accuracy on test data is: 0.88, averaged accuracy on train data is: 0.868
# This took 105 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8703333333333333 when classification threshold and k-folds are (0.68, 10) respectively.
#
# Accuracy on test data is: 0.87, averaged accuracy on train data is: 0.872
# This took 106 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8701818181818182 when classification threshold and k-folds are (0.68, 20) respectively.
#
# Accuracy on test data is: 0.87, averaged accuracy on train data is: 0.8719999999999999
# This took 107 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8702222222222222 when classification threshold and k-folds are (0.68, 25) respectively.
#
# Accuracy on test data is: 0.87, averaged accuracy on train data is: 0.8730000000000004
# This took 108 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8701153846153846 when classification threshold and k-folds are (0.68, 50) respectively.
#
# Accuracy on test data is: 0.87, averaged accuracy on train data is: 0.873
# This took 108 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8728431372549019 when classification threshold and k-folds are (0.68, 100) respectively.
#
# Accuracy on test data is: 0.874, averaged accuracy on train data is: 0.8149999999999998
# This took 108 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.872009900990099 when classification threshold and k-folds are (0.68, 200) respectively.
#
# Accuracy on test data is: 0.872, averaged accuracy on train data is: 0.873
# This took 108 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8699721115537848 when classification threshold and k-folds are (0.68, 500) respectively.
#
# Accuracy on test data is: 0.87, averaged accuracy on train data is: 0.863
# This took 108 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8698333333333333 when classification threshold and k-folds are (0.69, 10) respectively.
#
# Accuracy on test data is: 0.87, averaged accuracy on train data is: 0.8690000000000001
# This took 110 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8681818181818182 when classification threshold and k-folds are (0.69, 20) respectively.
#
# Accuracy on test data is: 0.868, averaged accuracy on train data is: 0.8699999999999999
# This took 111 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8681481481481481 when classification threshold and k-folds are (0.69, 25) respectively.
#
# Accuracy on test data is: 0.868, averaged accuracy on train data is: 0.8700000000000003
# This took 111 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8681153846153846 when classification threshold and k-folds are (0.69, 50) respectively.
#
# Accuracy on test data is: 0.868, averaged accuracy on train data is: 0.8709999999999999
# This took 112 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8727843137254901 when classification threshold and k-folds are (0.69, 100) respectively.
#
# Accuracy on test data is: 0.874, averaged accuracy on train data is: 0.8119999999999999
# This took 112 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.868049504950495 when classification threshold and k-folds are (0.69, 200) respectively.
#
# Accuracy on test data is: 0.868, averaged accuracy on train data is: 0.873
# This took 112 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Weighted accuracy is 0.8659601593625498 when classification threshold and k-folds are (0.69, 500) respectively.
#
# Accuracy on test data is: 0.866, averaged accuracy on train data is: 0.856
# This took 112 seconds to solve.
#
#
# **The best overall accuracy on test data is so far standing at: 0.916076923076923 when classification threshold and k-folds are (0.41000000000000003, 50)
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}
#
#
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When classification threshold and k-folds are (0.41000000000000003, 50) respectively, the expected overall weighted accuracy on unseen data is: 0.916076923076923
# This module is 0.916 accurat on test data
# Whereas, averaged accuracy on train data is 0.856, and topped at 0.96
# This module takes 7 seconds to solve.
# Modules with similar accuracy (if any) have the following hyperparameters (hyperparameters:[weight accuracy, accuracy, max_accuracy_train, max_time]) : {}

# %% [markdown]
# #  Final Module
#
# When plugging the hyper parameters associated with the best average weighted accuracy I got when running the above code, I got a **0.914** accuracy when run on test data.

# %%
class SpamClassifier:
    def __init__(self,threshold_classifier):
        self.threshold_classifier= threshold_classifier
        
    def train(self, training_data):
        n_samples, n_features = training_data[:,1:].shape
        x= training_data[:,1:]
        y= training_data[:,0]
        x=np.concatenate((np.ones((training_data.shape[0],1), dtype =int),x), axis=1)
        #normal equation
        self.weights= np.dot(np.dot(np.linalg.inv(np.dot(x.T, x)), x.T), y)

    
    def predict(self, new_data):
        new_data = np.concatenate((np.ones((new_data.shape[0],1), dtype =int),new_data), axis=1)
        linear_model = np.dot(self.weights.T, new_data.T)
        return np.where(linear_model <= self.threshold_classifier,0,1)
    

def cross_validation(training_spam):
    max_accuracy = 0
    averaged_accuracy = 0
    x_training= training_spam[:,1:]
    y_training= training_spam[:,0]
    x = np.split(x_training, x_training.shape[0]/k_fold, axis=0)
    y = np.split(y_training, y_training.shape[0]/k_fold, axis=0)
    for i in range(len(x)):
        x_temp=np.concatenate(x[0:i]+x[i+1:])
        y_temp=np.concatenate(y[0:i]+y[i+1:])
        y_temp=y_temp.reshape(y_temp.shape[0],1)
        temp_data = np.concatenate((y_temp,x_temp), axis=1)
        classifier = SpamClassifier(threshold)
        classifier.train(temp_data)
        final_y_predict_temp = classifier.predict(x[i])
        accuracy = np.count_nonzero(final_y_predict_temp == y[i].reshape(final_y_predict_temp.shape))/final_y_predict_temp.shape[0]
        
        if accuracy > max_accuracy:
            max_accuracy = accuracy
            max_classifier= classifier
    return max_classifier

def create_classifier():
    classifier = cross_validation(training_spam)
    return classifier


classifier = create_classifier()

# %%
# run on test data
testing_spam = np.loadtxt(open("data/testing_spam.csv"), delimiter=",").astype(int)
test_data = testing_spam[:, 1:]
test_labels = testing_spam[:, 0]

predictions = classifier.predict(test_data)
accuracy = np.count_nonzero(predictions == test_labels)/test_labels.shape[0]
print(f"Accuracy on test data is: {accuracy}")
# Out:
# Accuracy on test data is: 0.916

# %%
def confusion_matrix(test_labels, predictions):
    tp = tn = fp = fn = 0
    for actual_value, predicted_value in zip(test_labels, predictions):
        if predicted_value == actual_value:
            if predicted_value == 1: 
                tp += 1
            else: 
                tn += 1
        else: 
            if predicted_value == 1:
                fp += 1
            else: 
                fn += 1
    confusion_matrix = np.array([[tn, fp], [fn, tp]])
    print('___Confusion Matrix and Statistics___'.center(80))
    print('*****************************************'.center(80))
    print()
    print('           Reference   ')
    print ('Prediction   0    1')
    print('  0       ', confusion_matrix[0, 0],'  ',  confusion_matrix[0, 1])
    print('  1       ', confusion_matrix[1, 0], '  ', confusion_matrix[1, 1])
    
    
    accuracy = (tn+tp) / test_labels.shape[0]
    print()
    precision_positive =  tp / (tp+fp)
    precision_negative = tn / (tn+fn)
    recall_positive =  tp/ (tp+fn)
    recall_negative = tn/ (tn+fp)
    
    f1_positive = 2*(precision_positive * recall_positive)/(precision_positive+recall_positive)
    f1_negative = 2*(precision_negative * recall_negative)/(precision_negative+recall_negative)
    print()
    print()
    print('         Precision   Recall  f1-score   Support  ')
    print ('      0 ', np.round(precision_negative,2),'      ', np.round(recall_negative,2),'  ', np.round(f1_negative,2), '     ', tn+fp )
    print ('      1 ', np.round(precision_positive,2),'      ', np.round(recall_positive,2), '  ', np.round(f1_positive,2),'      ', tp+fn )
    print()
    print('accuracy                    ', accuracy,'    ',test_labels.shape[0] )

confusion_matrix(test_labels, predictions)
# Out:
#                      ___Confusion Matrix and Statistics___
#                    *****************************************
#
#            Reference
# Prediction   0    1
#   0        277    24
#   1        18    181
#
#
#
#          Precision   Recall  f1-score   Support
#       0  0.94        0.92    0.93       301
#       1  0.88        0.91    0.9        199
#
# accuracy                     0.916      500
